# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Justi/mimic-iii-clinical-database-1.4/microbiologyevents/MICROBIOLOGYEVENTS.csv/MICROBIOLOGYEVENTS.csv")
df.head(10)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            CHARTDATE            CHARTTIME  \
# 0     744          96   170324  2156-04-13 00:00:00  2156-04-13 14:18:00
# 1     745          96   170324  2156-04-20 00:00:00  2156-04-20 13:10:00
# 2     746          96   170324  2156-04-20 00:00:00  2156-04-20 16:00:00
# 3     747          96   170324  2156-04-20 00:00:00                  NaN
# 4     748          96   170324  2156-04-20 00:00:00                  NaN
# 5     749          96   170324  2156-04-21 00:00:00  2156-04-21 14:00:00
# 6     750         101   175533  2196-09-26 00:00:00                  NaN
# 7     751         101   175533  2196-09-27 00:00:00  2196-09-27 00:00:00
# 8     752         101   175533  2196-09-27 00:00:00  2196-09-27 00:00:00
# 9     753         101   175533  2196-09-27 00:00:00  2196-09-27 00:00:00
#
#    SPEC_ITEMID          SPEC_TYPE_DESC  ORG_ITEMID                ORG_NAME  \
# 0      70021.0  BRONCHOALVEOLAR LAVAGE     80026.0  PSEUDOMONAS AERUGINOSA
# ...

# %%
df_new = df[~df['ORG_NAME'].isna()]

# %%
organisms = np.unique(df_new['ORG_NAME'])

# %%
df_org = pd.DataFrame({'org_name':organisms})
df_org.to_csv("C:/Users/Justi/mimic-iii-clinical-database-1.4/microbiologyevents/MICROBIOLOGYEVENTS.csv/AROs/organisms.csv", index_label = 'Index')

# %%
df_MRSA = df[df['ORG_NAME'] == 'POSITIVE FOR METHICILLIN RESISTANT STAPH AUREUS']
# df_MRSA.to_csv("C:/Users/Justi/mimic-iii-clinical-database-1.4/microbiologyevents/MICROBIOLOGYEVENTS.csv/AROs/organisms_MRSA.csv", index_label = 'Index')
display(df_MRSA)
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID            CHARTDATE            CHARTTIME  \
# 1163      1201         124   138376  2166-01-09 00:00:00  2166-01-09 14:47:00
# 1164      1202         124   138376  2166-01-13 00:00:00  2166-01-13 08:43:00
# 1191      1229         124   138376  2166-01-20 00:00:00  2166-01-20 12:22:00
# 1193      1231         124   138376  2166-01-27 00:00:00  2166-01-27 14:30:00
# 3148      2847         267   163714  2156-06-07 00:00:00  2156-06-07 11:42:00
# ...        ...         ...      ...                  ...                  ...
# 630533  630073       99538   128902  2180-03-13 00:00:00  2180-03-13 02:02:00
# 630607  631112       99822   195871  2197-07-04 00:00:00  2197-07-04 19:42:00
# 630917  628008       99096   129330  2109-01-09 00:00:00  2109-01-09 19:51:00
# 630969  628977       99333   136029  2125-02-28 00:00:00  2125-02-28 02:37:00
# 631244  626035       98584   163688  2102-01-31 00:00:00  2102-01-31 10:42:00
#
# ...

# %%
df_admissions = pd.read_csv("C:/Users/Justi/mimic-iii-clinical-database-1.4/admissions/ADMISSIONS.csv/ADMISSIONS.csv")
display(df_admissions)
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0          21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1          22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2          23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3          24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4          25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
# ...       ...         ...      ...                  ...                  ...
# 58971   58594       98800   191113  2131-03-30 21:13:00  2131-04-02 15:02:00
# 58972   58595       98802   101071  2151-03-05 20:00:00  2151-03-06 09:10:00
# 58973   58596       98805   122631  2200-09-12 07:15:00  2200-09-20 12:08:00
# 58974   58597       98813   170407  2128-11-11 02:29:00  2128-12-22 13:11:00
# 58975   58598       98813   190264  2131-10-25 03:09:00  2131-10-26 17:44:00
#
# ...

# %%
inner_merged = pd.merge(df_MRSA,df_admissions, on=["HADM_ID"])

# %%
inner_merged.shape
# Out:
# (2104, 34)

# %%
display(inner_merged)
# Out:
#       ROW_ID_x  SUBJECT_ID_x  HADM_ID            CHARTDATE  \
# 0         1201           124   138376  2166-01-09 00:00:00
# 1         1202           124   138376  2166-01-13 00:00:00
# 2         1229           124   138376  2166-01-20 00:00:00
# 3         1231           124   138376  2166-01-27 00:00:00
# 4         2847           267   163714  2156-06-07 00:00:00
# ...        ...           ...      ...                  ...
# 2099    630073         99538   128902  2180-03-13 00:00:00
# 2100    631112         99822   195871  2197-07-04 00:00:00
# 2101    628008         99096   129330  2109-01-09 00:00:00
# 2102    628977         99333   136029  2125-02-28 00:00:00
# 2103    626035         98584   163688  2102-01-31 00:00:00
#
#                 CHARTTIME  SPEC_ITEMID SPEC_TYPE_DESC  ORG_ITEMID  \
# 0     2166-01-09 14:47:00      70091.0    MRSA SCREEN     80293.0
# 1     2166-01-13 08:43:00      70091.0    MRSA SCREEN     80293.0
# ...

# %%
inner_merged.to_csv("C:/Users/Justi/mimic-iii-clinical-database-1.4/microbiologyevents/MICROBIOLOGYEVENTS.csv/AROs/organisms_MRSA_ADMISSIONS_INNER_JOIN_HADMID.csv", index_label = 'Index')

# %%
# Out:
#   File "C:\Users\Justi\AppData\Local\Temp\ipykernel_14196\2419508657.py", line 1
#     "C:/Users/Justi/mimic-iii-clinical-database-1.4/microbiologyevents/MICROBIOLOGYEVENTS.csv/AROs/organisms_MRSA_ADMISSIONS_INNER_JOIN.csv", index_label = 'Index'
#     ^
# SyntaxError: cannot assign to literal

# %%
df_test = df_admissions[df_admissions['HADM_ID'] == 138376]

# %%
df_test
# Out:
#      ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 130     169         124   138376  2165-12-31 18:55:00  2166-02-01 06:55:00
#
#                DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 130  2166-02-01 06:55:00      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
#
#     DISCHARGE_LOCATION INSURANCE LANGUAGE  RELIGION MARITAL_STATUS ETHNICITY  \
# 130       DEAD/EXPIRED  Medicare     ENGL  CATHOLIC        MARRIED     WHITE
#
#     EDREGTIME EDOUTTIME                            DIAGNOSIS  \
# 130       NaN       NaN  PNEUMONIA;CHRONIC OBST PULM DISEASE
#
#      HOSPITAL_EXPIRE_FLAG  HAS_CHARTEVENTS_DATA
# 130                     1                     1
